# %% [markdown]
# <a href="https://colab.research.google.com/github/isadora-oa/imersao-dados-desafio-final/blob/main/Notebooks/Aula_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Dados

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression='zip')
mapa = {'droga' : 'composto'}
dados.columns = dados.columns.str.replace('-', '')
dados.rename(columns=mapa, inplace=True)
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ### Comandos

# %%
pd.crosstab([dados['dose'], dados['tempo']] , [dados['tratamento']])
#Agragador que imprime uma tabela de frequência, para a tabela geral(todos os genes e tipos celulares)

#Outros agregadores: pd.melt(), concatenado., aggfunc=''
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']] , [dados['tratamento']] , normalize='index')   #Em porcentagem
                                                                      #'index' ou True
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']] , [dados['tratamento']] , normalize='columns')
#Normaliza através da(s) coluna(s)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %%
#Outra forma de gerar estas mesmas tabelas, concatenado (groupby)

#definição das variáveis:
com_controle = dados[dados['tratamento']=='com_controle'].groupby(['dose','tempo']).count()['tratamento']
com_droga = dados[dados['tratamento']=='com_droga'].groupby(['dose','tempo']).count()['tratamento']

#fórmulas:
concatenado = pd.concat([com_controle,com_droga], axis=1)
concatenado.columns = ['com_controle','com_droga']  #altera o nome das colunas

concatenado
# Out:
#             com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
concatenado.div(concatenado.sum(axis=1),axis=0)  #normaliza os valores
# Out:
#             com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']] , [dados['tratamento']] , values=dados['g0'], aggfunc='mean')
#Valores para um dado (gene ou tipo celular) específico, no caso o g0
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# ### Gráfico g0 x g3

# %%
dados[['g0', 'g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=dados, x='g0', y='g3')
plt.show()

# %% [markdown]
# ### Gráficos g0 x g8

# %%
import matplotlib.pyplot as plt

sns.scatterplot(data=dados, x='g0', y='g8')
plt.show()

# %%
import matplotlib.pyplot as plt

sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color': 'black'})
#Com linha de tendência
plt.show()

# %%
import matplotlib.pyplot as plt
#Adicionados mais parâmetros, para plotar somente os dados referentes ao tratamento
sns.lmplot(data=dados, x='g0', y='g8', col='tratamento', row='tempo', line_kws={'color': 'black'})
#                      Dados da tabela:   |coluna           |linha
plt.show()

# %% [markdown]
# ### **Correlação entre os dados**
#
# ---

# %% [markdown]
# *   *Valores próximos de -1 ou +1 indicam variáveis altamente correlacionadas;*
# *   *Valores próximos de 0 indicam variáveis não corrrelacionadas;*
# *   *Quando os valores são negativos (próximos de -1) as variáveis são inversamente correlacionadas, ou seja, enquanto uma aumenta a outra diminui proporcionalmente;*
# *   *Quando os valores são positivos (próximos de +1) as variáveis são diretamente correlacionadas, ou seja, ambas diminuem/aumentam proporcionalmente;*
#
# *A alta ou baixa correlação não implica necessariamente na causalidade do evento. É preciso analisar outros fatores para se chegar a uma conlcusão sobre a causalidade.*

# %%
dados.loc[:, 'g0':'g771'].corr()
#Correlaciona todos os parâmetros (tratamento, tempo, composto e dose) de todos os genes
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
#Código copiado do Seaborn: 'https://seaborn.pydata.org/examples/many_pairwise_correlations.html'

import numpy as np

corr = dados.loc[:, 'g0': 'g30'].corr()
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, #vmax=.3,(alteração relacionada com a escala do gráfico)
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %%
dados.loc[:, 'c0':'c99'].corr()  #Para os tipos celulares
# Out:
#            c0        c1        c2  ...       c97       c98       c99
# c0   1.000000  0.827336  0.848472  ...  0.834513  0.800682  0.777426
# c1   0.827336  1.000000  0.901416  ...  0.866084  0.815952  0.781510
# c2   0.848472  0.901416  1.000000  ...  0.874869  0.839640  0.802032
# c3   0.798830  0.808364  0.830759  ...  0.814889  0.779998  0.768872
# c4   0.840695  0.879258  0.909991  ...  0.873534  0.834823  0.795218
# ..        ...       ...       ...  ...       ...       ...       ...
# c95  0.815499  0.803637  0.837420  ...  0.811155  0.787529  0.758110
# c96  0.845579  0.871383  0.898270  ...  0.863061  0.819600  0.789649
# c97  0.834513  0.866084  0.874869  ...  1.000000  0.801809  0.775300
# c98  0.800682  0.815952  0.839640  ...  0.801809  1.000000  0.755991
# c99  0.777426  0.781510  0.802032  ...  0.775300  0.755991  1.000000
#
# [100 rows x 100 columns]

# %%
import numpy as np

corr = dados.loc[:, 'c0': 'c30'].corr()  #Seleciona quais dados plotar no gráfico
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [markdown]
# ***Os tipos celulares*** influenciam na sobrevivência do organismo e ***estão correlacionados***, ou seja, se um tipo celular for afetado ou não provavelmente os demais também terão os mesmo compotamento, como mostra o gráfico 'nome no gráfico'.

# %%
corr_gc = dados.loc[:,'g0':'c99'].corr()  #Para genes(g) e tipos celulares(c)

corr_gc
# Out:
#            g0        g1        g2  ...       c97       c98       c99
# g0   1.000000  0.086032  0.176188  ... -0.622840 -0.640484 -0.609238
# g1   0.086032  1.000000 -0.054518  ... -0.008487 -0.002824 -0.002308
# g2   0.176188 -0.054518  1.000000  ... -0.178812 -0.170152 -0.172124
# g3   0.011266 -0.027855  0.042633  ... -0.049951 -0.079855 -0.037579
# g4   0.403153  0.193647  0.013968  ... -0.394904 -0.366693 -0.390581
# ..        ...       ...       ...  ...       ...       ...       ...
# c95 -0.600758 -0.011237 -0.158105  ...  0.811155  0.787529  0.758110
# c96 -0.646784 -0.022127 -0.182540  ...  0.863061  0.819600  0.789649
# c97 -0.622840 -0.008487 -0.178812  ...  1.000000  0.801809  0.775300
# c98 -0.640484 -0.002824 -0.170152  ...  0.801809  1.000000  0.755991
# c99 -0.609238 -0.002308 -0.172124  ...  0.775300  0.755991  1.000000
#
# [872 rows x 872 columns]

# %%
import numpy as np

corr = corr_gc.loc['g0':'g30','c0':'c30']
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()
